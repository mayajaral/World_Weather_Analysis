# %%
# Import the requests library.
import requests
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt

# Import the API key.
from config import weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Create an endpoint URL for a city.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 35.4,
#   'feels_like': 24.57,
#   'temp_min': 33.8,
#   'temp_max': 37,
#   'pressure': 1027,
#   'humidity': 37},
#  'visibility': 10000,
#  'wind': {'speed': 9.17, 'deg': 200},
#  'clouds': {'all': 90},
#  'dt': 1609353739,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1609330395,
#   'sunset': 1609363229},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
#city_weather.json()
# Parse out the needed data.

city_weather_description = city_weather["weather"][0]['description']
city_weather_description
# Out:
# 'overcast clouds'

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gorin
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | vao
# Processing Record 7 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | inyonga
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | alofi
# Processing Record 13 of Set 1 | xinzhi
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | jibuti
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | darnah
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | mombasa
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | tucumcari
# Processing Record 25 of Set 1 | newport
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 30 of Set 1 | jalu
# Processing Record 31 of Set 1 | salalah
# Processing Record 32 of Set 1 | faya
# Processing Record 33 of Set 1 | pointe michel
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | beringovskiy
# Processing Record 37 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 1 | ternate
# Processing Record 39 of Set 1 | makhu
# Processing Record 40 of Set 1 | del rio
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | lethem
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | havre-saint-pierre
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | westport
# Processing Record 2 of Set 2 | mul
# Processing Record 3 of Set 2 | akyab
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | nador
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | chingola
# Processing Record 8 of Set 2 | dehra dun
# Processing Record 9 of Set 2 | kemang
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | la palma
# Processing Record 13 of Set 2 | yerbogachen
# Processing Record 14 of Set 2 | bintulu
# Processing Record 15 of Set 2 | bahia blanca
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | taoudenni
# Processing Record 19 of Set 2 | tadine
# Processing Record 20 of Set 2 | iowa city
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | baglung
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | aginskoye
# Processing Record 27 of Set 2 | thap than
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | marsa matruh
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | zhigansk
# Processing Record 40 of Set 2 | itarema
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | gidole
# Processing Record 43 of Set 2 | sarany
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | igarka
# Processing Record 46 of Set 2 | qasigiannguit
# Processing Record 47 of Set 2 | gizo
# Processing Record 48 of Set 2 | alice springs
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | teknaf
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | karratha
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | asyut
# Processing Record 7 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 3 | datong
# Processing Record 9 of Set 3 | suicheng
# Processing Record 10 of Set 3 | mehamn
# Processing Record 11 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | kudahuvadhoo
# Processing Record 14 of Set 3 | inhambane
# Processing Record 15 of Set 3 | saryg-sep
# Processing Record 16 of Set 3 | riyadh
# Processing Record 17 of Set 3 | nalut
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | esso
# Processing Record 20 of Set 3 | tabory
# Processing Record 21 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 3 | santo tomas
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | buin
# Processing Record 25 of Set 3 | kedarnath
# City not found. Skipping...
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | diffa
# Processing Record 31 of Set 3 | krasnoslobodsk
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | wad rawah
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 3 | sayyan
# Processing Record 40 of Set 3 | prince rupert
# Processing Record 41 of Set 3 | ushuaia
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | tabursuq
# Processing Record 44 of Set 3 | yerofey pavlovich
# Processing Record 45 of Set 3 | zapadnaya dvina
# Processing Record 46 of Set 3 | hami
# Processing Record 47 of Set 3 | qaanaaq
# Processing Record 48 of Set 3 | petauke
# Processing Record 49 of Set 3 | porto novo
# Processing Record 50 of Set 3 | fiditi
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | grindavik
# Processing Record 3 of Set 4 | lorica
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | chum phae
# Processing Record 6 of Set 4 | vila do maio
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | nahrin
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | catuday
# Processing Record 11 of Set 4 | babra
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | zhuanghe
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | kieta
# Processing Record 19 of Set 4 | la ronge
# Processing Record 20 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 4 | eureka
# Processing Record 22 of Set 4 | harper
# Processing Record 23 of Set 4 | dhidhdhoo
# Processing Record 24 of Set 4 | ayagoz
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | santa fe
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 29 of Set 4 | prieska
# Processing Record 30 of Set 4 | udachnyy
# Processing Record 31 of Set 4 | vagur
# Processing Record 32 of Set 4 | inta
# Processing Record 33 of Set 4 | zambezi
# Processing Record 34 of Set 4 | krasnoselkup
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | arnedo
# Processing Record 37 of Set 4 | severo-kurilsk
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | kokopo
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | wajima
# Processing Record 42 of Set 4 | meulaboh
# Processing Record 43 of Set 4 | hyeres
# Processing Record 44 of Set 4 | woodstock
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | vallenar
# Processing Record 48 of Set 4 | svetlograd
# Processing Record 49 of Set 4 | maragogi
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | bloomingdale
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | henties bay
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | vila franca do campo
# Processing Record 7 of Set 5 | charters towers
# Processing Record 8 of Set 5 | eyrarbakki
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 5 | jonesboro
# Processing Record 14 of Set 5 | eydhafushi
# Processing Record 15 of Set 5 | sitangkai
# Processing Record 16 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 5 | huarmey
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | san cristobal
# Processing Record 20 of Set 5 | luderitz
# Processing Record 21 of Set 5 | porto walter
# Processing Record 22 of Set 5 | kawalu
# Processing Record 23 of Set 5 | rupert
# Processing Record 24 of Set 5 | yovon
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | hofn
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | naantali
# Processing Record 29 of Set 5 | kormilovka
# Processing Record 30 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 31 of Set 5 | sao luiz gonzaga
# Processing Record 32 of Set 5 | xichang
# Processing Record 33 of Set 5 | benguela
# Processing Record 34 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | chokurdakh
# Processing Record 38 of Set 5 | ilhabela
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | dawlatabad
# Processing Record 44 of Set 5 | yei
# Processing Record 45 of Set 5 | talcahuano
# Processing Record 46 of Set 5 | marrakesh
# Processing Record 47 of Set 5 | rabat
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | california city
# Processing Record 50 of Set 5 | petrolina de goias
# Processing Record 1 of Set 6 | bondoukou
# Processing Record 2 of Set 6 | salinopolis
# Processing Record 3 of Set 6 | gazanjyk
# Processing Record 4 of Set 6 | kavaratti
# Processing Record 5 of Set 6 | mahur
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | belyy yar
# Processing Record 8 of Set 6 | casablanca
# Processing Record 9 of Set 6 | kysyl-syr
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | okahandja
# Processing Record 12 of Set 6 | belen
# Processing Record 13 of Set 6 | saint george
# Processing Record 14 of Set 6 | kenai
# Processing Record 15 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 6 | acari
# Processing Record 17 of Set 6 | cape town
# Processing Record 18 of Set 6 | serenje
# Processing Record 19 of Set 6 | andra
# Processing Record 20 of Set 6 | sistranda
# Processing Record 21 of Set 6 | narsaq
# Processing Record 22 of Set 6 | shenjiamen
# Processing Record 23 of Set 6 | husavik
# Processing Record 24 of Set 6 | boende
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | dingle
# Processing Record 27 of Set 6 | nikolskoye
# Processing Record 28 of Set 6 | lodja
# Processing Record 29 of Set 6 | lolodorf
# Processing Record 30 of Set 6 | kautokeino
# Processing Record 31 of Set 6 | totness
# Processing Record 32 of Set 6 | inuvik
# Processing Record 33 of Set 6 | bushehr
# Processing Record 34 of Set 6 | damietta
# Processing Record 35 of Set 6 | ossora
# Processing Record 36 of Set 6 | madimba
# Processing Record 37 of Set 6 | chulman
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | lahan
# Processing Record 40 of Set 6 | mackay
# Processing Record 41 of Set 6 | lorengau
# Processing Record 42 of Set 6 | shimoda
# Processing Record 43 of Set 6 | tessalit
# Processing Record 44 of Set 6 | san pedro
# Processing Record 45 of Set 6 | wasilla
# Processing Record 46 of Set 6 | negombo
# Processing Record 47 of Set 6 | wittenheim
# Processing Record 48 of Set 6 | burica
# City not found. Skipping...
# Processing Record 49 of Set 6 | mozarlandia
# Processing Record 50 of Set 6 | gzhatsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | saint-pierre
# Processing Record 2 of Set 7 | half moon bay
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 7 | iracoubo
# Processing Record 6 of Set 7 | roma
# Processing Record 7 of Set 7 | manuk mangkaw
# Processing Record 8 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 7 | waitati
# Processing Record 10 of Set 7 | iquitos
# Processing Record 11 of Set 7 | atbasar
# Processing Record 12 of Set 7 | coihaique
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | mocuba
# Processing Record 15 of Set 7 | murray
# Processing Record 16 of Set 7 | rawson
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | conceicao da barra
# Processing Record 19 of Set 7 | bileca
# Processing Record 20 of Set 7 | kodiak
# Processing Record 21 of Set 7 | wakkanai
# Processing Record 22 of Set 7 | omboue
# Processing Record 23 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | saint-francois
# Processing Record 26 of Set 7 | valley city
# Processing Record 27 of Set 7 | gilgit
# Processing Record 28 of Set 7 | moerai
# Processing Record 29 of Set 7 | zaltan
# Processing Record 30 of Set 7 | petropavlovka
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | nome
# Processing Record 35 of Set 7 | fiumicino
# Processing Record 36 of Set 7 | sorong
# Processing Record 37 of Set 7 | vitoria da conquista
# Processing Record 38 of Set 7 | la asuncion
# Processing Record 39 of Set 7 | prado
# Processing Record 40 of Set 7 | disna
# Processing Record 41 of Set 7 | samana
# Processing Record 42 of Set 7 | honiara
# Processing Record 43 of Set 7 | redlands
# Processing Record 44 of Set 7 | shakhunya
# Processing Record 45 of Set 7 | guerrero negro
# Processing Record 46 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 47 of Set 7 | bukama
# Processing Record 48 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 7 | nueva loja
# Processing Record 50 of Set 7 | kazerun
# Processing Record 1 of Set 8 | rocha
# Processing Record 2 of Set 8 | banfora
# Processing Record 3 of Set 8 | kaniama
# Processing Record 4 of Set 8 | kristiansund
# Processing Record 5 of Set 8 | hamilton
# Processing Record 6 of Set 8 | mezen
# Processing Record 7 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 8 | grand gaube
# Processing Record 12 of Set 8 | asau
# Processing Record 13 of Set 8 | ambon
# Processing Record 14 of Set 8 | talara
# Processing Record 15 of Set 8 | sambava
# Processing Record 16 of Set 8 | izvor
# Processing Record 17 of Set 8 | sedhiou
# Processing Record 18 of Set 8 | allapalli
# Processing Record 19 of Set 8 | khandyga
# Processing Record 20 of Set 8 | green river
# Processing Record 21 of Set 8 | margate
# Processing Record 22 of Set 8 | aloleng
# Processing Record 23 of Set 8 | norman wells
# Processing Record 24 of Set 8 | hakvik
# City not found. Skipping...
# Processing Record 25 of Set 8 | yulara
# Processing Record 26 of Set 8 | gua musang
# Processing Record 27 of Set 8 | antofagasta
# Processing Record 28 of Set 8 | kolyvan
# Processing Record 29 of Set 8 | bama
# Processing Record 30 of Set 8 | vondrozo
# Processing Record 31 of Set 8 | amazar
# Processing Record 32 of Set 8 | jiangyan
# Processing Record 33 of Set 8 | brae
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 8 | jasper
# Processing Record 38 of Set 8 | erenhot
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | borisoglebskiy
# Processing Record 41 of Set 8 | komsomolskiy
# Processing Record 42 of Set 8 | plouzane
# Processing Record 43 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 8 | muhos
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | hunchun
# Processing Record 47 of Set 8 | fatehpur
# Processing Record 48 of Set 8 | hole narsipur
# Processing Record 49 of Set 8 | liepaja
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | novosokolniki
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 9 | korla
# Processing Record 5 of Set 9 | sao jose da coroa grande
# Processing Record 6 of Set 9 | kawambwa
# Processing Record 7 of Set 9 | golden
# Processing Record 8 of Set 9 | ongandjera
# Processing Record 9 of Set 9 | montreal
# Processing Record 10 of Set 9 | cocorit
# Processing Record 11 of Set 9 | muli
# Processing Record 12 of Set 9 | alta floresta
# Processing Record 13 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | aasiaat
# Processing Record 16 of Set 9 | tarko-sale
# Processing Record 17 of Set 9 | houyet
# Processing Record 18 of Set 9 | mackenzie
# Processing Record 19 of Set 9 | berlin
# Processing Record 20 of Set 9 | moorhead
# Processing Record 21 of Set 9 | maniago
# Processing Record 22 of Set 9 | avera
# Processing Record 23 of Set 9 | desnogorsk
# Processing Record 24 of Set 9 | basco
# Processing Record 25 of Set 9 | poum
# Processing Record 26 of Set 9 | igra
# Processing Record 27 of Set 9 | jand
# Processing Record 28 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | marystown
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | the valley
# Processing Record 32 of Set 9 | northam
# Processing Record 33 of Set 9 | bhadravati
# Processing Record 34 of Set 9 | songling
# Processing Record 35 of Set 9 | kurchum
# Processing Record 36 of Set 9 | pimenta bueno
# Processing Record 37 of Set 9 | iqaluit
# Processing Record 38 of Set 9 | maniitsoq
# Processing Record 39 of Set 9 | dandong
# Processing Record 40 of Set 9 | imamoglu
# Processing Record 41 of Set 9 | borovoy
# Processing Record 42 of Set 9 | ouesso
# Processing Record 43 of Set 9 | baykalsk
# Processing Record 44 of Set 9 | lavrentiya
# Processing Record 45 of Set 9 | verkhoyansk
# Processing Record 46 of Set 9 | bakel
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | los llanos de aridane
# Processing Record 49 of Set 9 | nova vicosa
# Processing Record 50 of Set 9 | encruzilhada
# Processing Record 1 of Set 10 | tortoli
# Processing Record 2 of Set 10 | padang
# Processing Record 3 of Set 10 | paita
# Processing Record 4 of Set 10 | sept-iles
# Processing Record 5 of Set 10 | ahipara
# Processing Record 6 of Set 10 | taksimo
# Processing Record 7 of Set 10 | mogadishu
# Processing Record 8 of Set 10 | college
# Processing Record 9 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 10 of Set 10 | polunochnoye
# Processing Record 11 of Set 10 | eyl
# Processing Record 12 of Set 10 | emerald
# Processing Record 13 of Set 10 | belmonte
# Processing Record 14 of Set 10 | gushikawa
# Processing Record 15 of Set 10 | kulhudhuffushi
# Processing Record 16 of Set 10 | imbituba
# Processing Record 17 of Set 10 | lagoa
# Processing Record 18 of Set 10 | fort smith
# Processing Record 19 of Set 10 | kibara
# Processing Record 20 of Set 10 | kwinana
# Processing Record 21 of Set 10 | sechura
# Processing Record 22 of Set 10 | corn island
# Processing Record 23 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 10 | paamiut
# Processing Record 25 of Set 10 | dana point
# Processing Record 26 of Set 10 | xuddur
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | karaton
# Processing Record 29 of Set 10 | kirakira
# Processing Record 30 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 31 of Set 10 | iwanai
# Processing Record 32 of Set 10 | flinders
# Processing Record 33 of Set 10 | miri
# Processing Record 34 of Set 10 | katsuura
# Processing Record 35 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 10 | keetmanshoop
# Processing Record 37 of Set 10 | storsteinnes
# Processing Record 38 of Set 10 | gavrilov-yam
# Processing Record 39 of Set 10 | monroe
# Processing Record 40 of Set 10 | jos
# Processing Record 41 of Set 10 | isangel
# Processing Record 42 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 10 | taft
# Processing Record 44 of Set 10 | santa lucia
# Processing Record 45 of Set 10 | aktanysh
# Processing Record 46 of Set 10 | palauig
# Processing Record 47 of Set 10 | quesnel
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | kjollefjord
# Processing Record 50 of Set 10 | tilichiki
# Processing Record 1 of Set 11 | cherskiy
# Processing Record 2 of Set 11 | ayer tawar
# Processing Record 3 of Set 11 | altay
# Processing Record 4 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 11 | port lincoln
# Processing Record 6 of Set 11 | hurghada
# Processing Record 7 of Set 11 | marienburg
# Processing Record 8 of Set 11 | camopi
# Processing Record 9 of Set 11 | greenwood
# Processing Record 10 of Set 11 | abbeville
# Processing Record 11 of Set 11 | victoria
# Processing Record 12 of Set 11 | praia da vitoria
# Processing Record 13 of Set 11 | pandan
# Processing Record 14 of Set 11 | seybaplaya
# Processing Record 15 of Set 11 | palmer
# Processing Record 16 of Set 11 | waipawa
# Processing Record 17 of Set 11 | dawei
# Processing Record 18 of Set 11 | kiama
# Processing Record 19 of Set 11 | meadow lake
# Processing Record 20 of Set 11 | bocana de paiwas
# Processing Record 21 of Set 11 | ngunguru
# Processing Record 22 of Set 11 | ormond beach
# Processing Record 23 of Set 11 | ponta delgada
# Processing Record 24 of Set 11 | miles city
# Processing Record 25 of Set 11 | cap malheureux
# Processing Record 26 of Set 11 | olga
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | tombouctou
# Processing Record 29 of Set 11 | langsa
# Processing Record 30 of Set 11 | nerchinskiy zavod
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | booue
# Processing Record 33 of Set 11 | lagos
# Processing Record 34 of Set 11 | usinsk
# Processing Record 35 of Set 11 | cervo
# Processing Record 36 of Set 11 | upata
# Processing Record 37 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 38 of Set 11 | praia
# Processing Record 39 of Set 11 | ostersund
# Processing Record 40 of Set 11 | wawa
# Processing Record 41 of Set 11 | norsup
# Processing Record 42 of Set 11 | stokmarknes
# Processing Record 43 of Set 11 | zomin
# Processing Record 44 of Set 11 | goderich
# Processing Record 45 of Set 11 | djibo
# Processing Record 46 of Set 11 | melchor de mencos
# Processing Record 47 of Set 11 | primorsk
# Processing Record 48 of Set 11 | camana
# Processing Record 49 of Set 11 | caravelas
# Processing Record 50 of Set 11 | jinji
# Processing Record 1 of Set 12 | ha tinh
# Processing Record 2 of Set 12 | xining
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | sao filipe
# Processing Record 5 of Set 12 | olinda
# Processing Record 6 of Set 12 | cairns
# Processing Record 7 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 12 | gawler
# Processing Record 9 of Set 12 | santa rosa
# Processing Record 10 of Set 12 | alyangula
# Processing Record 11 of Set 12 | tete
# Processing Record 12 of Set 12 | puerto escondido
# Processing Record 13 of Set 12 | tutoia
# Processing Record 14 of Set 12 | fuyu
# Processing Record 15 of Set 12 | ust-maya
# Processing Record 16 of Set 12 | vardo
# Processing Record 17 of Set 12 | wanning
# Processing Record 18 of Set 12 | provideniya
# Processing Record 19 of Set 12 | santiago
# Processing Record 20 of Set 12 | songkhla
# Processing Record 21 of Set 12 | pacifica
# Processing Record 22 of Set 12 | pimentel
# Processing Record 23 of Set 12 | atar
# Processing Record 24 of Set 12 | hohhot
# Processing Record 25 of Set 12 | leinefelde
# Processing Record 26 of Set 12 | jacareacanga
# Processing Record 27 of Set 12 | olafsvik
# Processing Record 28 of Set 12 | saryozek
# Processing Record 29 of Set 12 | yerkoy
# Processing Record 30 of Set 12 | oliveira dos brejinhos
# Processing Record 31 of Set 12 | dneprovskaya
# Processing Record 32 of Set 12 | lebedinyy
# Processing Record 33 of Set 12 | jagatsinghapur
# Processing Record 34 of Set 12 | homer
# Processing Record 35 of Set 12 | kingaroy
# Processing Record 36 of Set 12 | matara
# Processing Record 37 of Set 12 | ustye
# Processing Record 38 of Set 12 | sao raimundo nonato
# Processing Record 39 of Set 12 | tazovskiy
# Processing Record 40 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | caucaia
# Processing Record 43 of Set 12 | alice town
# Processing Record 44 of Set 12 | salekhard
# Processing Record 45 of Set 12 | marsh harbour
# Processing Record 46 of Set 12 | sakakah
# Processing Record 47 of Set 12 | batagay-alyta
# Processing Record 48 of Set 12 | batagay
# Processing Record 49 of Set 12 | heidelberg
# Processing Record 50 of Set 12 | key west
# Processing Record 1 of Set 13 | vestmannaeyjar
# Processing Record 2 of Set 13 | antalaha
# Processing Record 3 of Set 13 | teahupoo
# Processing Record 4 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 13 | umm kaddadah
# Processing Record 6 of Set 13 | amahai
# Processing Record 7 of Set 13 | acarau
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | ulaangom
# Processing Record 10 of Set 13 | wahiawa
# Processing Record 11 of Set 13 | broken hill
# Processing Record 12 of Set 13 | aktau
# Processing Record 13 of Set 13 | gewane
# Processing Record 14 of Set 13 | junnar
# Processing Record 15 of Set 13 | point fortin
# Processing Record 16 of Set 13 | madera
# Processing Record 17 of Set 13 | fukue
# Processing Record 18 of Set 13 | salamiyah
# Processing Record 19 of Set 13 | kuusamo
# Processing Record 20 of Set 13 | hualmay
# Processing Record 21 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 22 of Set 13 | aksarka
# Processing Record 23 of Set 13 | chicama
# Processing Record 24 of Set 13 | bac lieu
# Processing Record 25 of Set 13 | stangaceaua
# City not found. Skipping...
# Processing Record 26 of Set 13 | upala
# Processing Record 27 of Set 13 | camacari
# Processing Record 28 of Set 13 | lloydminster
# Processing Record 29 of Set 13 | la ligua
# Processing Record 30 of Set 13 | oranjemund
# Processing Record 31 of Set 13 | segovia
# Processing Record 32 of Set 13 | rorvik
# Processing Record 33 of Set 13 | san policarpo
# Processing Record 34 of Set 13 | santa vitoria do palmar
# Processing Record 35 of Set 13 | snina
# Processing Record 36 of Set 13 | morondava
# Processing Record 37 of Set 13 | kunming
# Processing Record 38 of Set 13 | copiapo
# Processing Record 39 of Set 13 | karmana
# City not found. Skipping...
# Processing Record 40 of Set 13 | kalach-na-donu
# Processing Record 41 of Set 13 | tanshui
# City not found. Skipping...
# Processing Record 42 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 13 | tigil
# Processing Record 44 of Set 13 | praya
# Processing Record 45 of Set 13 | maroantsetra
# Processing Record 46 of Set 13 | nizwa
# Processing Record 47 of Set 13 | coruripe
# Processing Record 48 of Set 13 | parati
# Processing Record 49 of Set 13 | masalli
# Processing Record 50 of Set 13 | tual
# Processing Record 1 of Set 14 | aswan
# Processing Record 2 of Set 14 | chimbote
# Processing Record 3 of Set 14 | port-cartier
# Processing Record 4 of Set 14 | amapa
# Processing Record 5 of Set 14 | pilar do sul
# Processing Record 6 of Set 14 | caidian
# Processing Record 7 of Set 14 | ouango
# Processing Record 8 of Set 14 | orchard homes
# Processing Record 9 of Set 14 | huejuquilla el alto
# Processing Record 10 of Set 14 | lapeer
# Processing Record 11 of Set 14 | richards bay
# Processing Record 12 of Set 14 | ndele
# Processing Record 13 of Set 14 | haputale
# Processing Record 14 of Set 14 | inirida
# Processing Record 15 of Set 14 | peniche
# Processing Record 16 of Set 14 | manta
# Processing Record 17 of Set 14 | evensk
# Processing Record 18 of Set 14 | nemuro
# Processing Record 19 of Set 14 | sabancuy
# Processing Record 20 of Set 14 | usevya
# Processing Record 21 of Set 14 | killybegs
# Processing Record 22 of Set 14 | egvekinot
# Processing Record 23 of Set 14 | yakshur-bodya
# City not found. Skipping...
# Processing Record 24 of Set 14 | phan thiet
# Processing Record 25 of Set 14 | pirovskoye
# Processing Record 26 of Set 14 | itum-kale
# Processing Record 27 of Set 14 | maputo
# Processing Record 28 of Set 14 | kemijarvi
# Processing Record 29 of Set 14 | dauriya
# Processing Record 30 of Set 14 | jijiga
# Processing Record 31 of Set 14 | san miguel
# Processing Record 32 of Set 14 | san andres
# Processing Record 33 of Set 14 | flin flon
# Processing Record 34 of Set 14 | kariba
# Processing Record 35 of Set 14 | yablochnyy
# Processing Record 36 of Set 14 | axim
# Processing Record 37 of Set 14 | lindon
# Processing Record 38 of Set 14 | yantal
# Processing Record 39 of Set 14 | montepuez
# Processing Record 40 of Set 14 | santiago de cao
# Processing Record 41 of Set 14 | dwarka
# Processing Record 42 of Set 14 | buchanan
# Processing Record 43 of Set 14 | qui nhon
# Processing Record 44 of Set 14 | deputatskiy
# Processing Record 45 of Set 14 | haines junction
# Processing Record 46 of Set 14 | sulangan
# Processing Record 47 of Set 14 | oudtshoorn
# Processing Record 48 of Set 14 | sturgeon bay
# Processing Record 49 of Set 14 | mikuni
# Processing Record 50 of Set 14 | alihe
# Processing Record 1 of Set 15 | sassandra
# Processing Record 2 of Set 15 | kefamenanu
# Processing Record 3 of Set 15 | baruun-urt
# Processing Record 4 of Set 15 | teya
# Processing Record 5 of Set 15 | mahon
# Processing Record 6 of Set 15 | sanhsia
# City not found. Skipping...
# Processing Record 7 of Set 15 | changzhou
# Processing Record 8 of Set 15 | celestun
# Processing Record 9 of Set 15 | ariquemes
# Processing Record 10 of Set 15 | bubaque
# Processing Record 11 of Set 15 | zhoucun
# Processing Record 12 of Set 15 | chardara
# Processing Record 13 of Set 15 | belaya gora
# Processing Record 14 of Set 15 | broome
# Processing Record 15 of Set 15 | creel
# Processing Record 16 of Set 15 | kloulklubed
# Processing Record 17 of Set 15 | houma
# Processing Record 18 of Set 15 | pitimbu
# Processing Record 19 of Set 15 | katangli
# Processing Record 20 of Set 15 | aitape
# Processing Record 21 of Set 15 | port-gentil
# Processing Record 22 of Set 15 | acaponeta
# Processing Record 23 of Set 15 | cheyenne
# Processing Record 24 of Set 15 | charagua
# Processing Record 25 of Set 15 | zemlyansk
# Processing Record 26 of Set 15 | mount isa
# Processing Record 27 of Set 15 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 28 of Set 15 | taltal
# Processing Record 29 of Set 15 | anadyr
# Processing Record 30 of Set 15 | mareeba
# Processing Record 31 of Set 15 | ayia marina
# Processing Record 32 of Set 15 | rincon de la victoria
# Processing Record 33 of Set 15 | tingo maria
# Processing Record 34 of Set 15 | leninskoye
# Processing Record 35 of Set 15 | dongying
# Processing Record 36 of Set 15 | nisia floresta
# Processing Record 37 of Set 15 | raudeberg
# Processing Record 38 of Set 15 | kununurra
# Processing Record 39 of Set 15 | sao gabriel da cachoeira
# Processing Record 40 of Set 15 | mecca
# Processing Record 41 of Set 15 | khasan
# Processing Record 42 of Set 15 | havelock
# Processing Record 43 of Set 15 | ondjiva
# Processing Record 44 of Set 15 | veraval
# Processing Record 45 of Set 15 | kabinda
# Processing Record 46 of Set 15 | perpignan
# Processing Record 47 of Set 15 | toora-khem
# Processing Record 48 of Set 15 | karaman
# Processing Record 49 of Set 15 | samarai
# Processing Record 50 of Set 15 | atambua
# Processing Record 1 of Set 16 | villazon
# Processing Record 2 of Set 16 | nyurba
# Processing Record 3 of Set 16 | roald
# Processing Record 4 of Set 16 | magistralnyy
# Processing Record 5 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 16 | brownsville
# Processing Record 7 of Set 16 | yaan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Gorin      RU  51.20  136.67    -15.50        87         100
# 1     Busselton      AU -33.65  115.33     68.13        72           0
# 2  Puerto Ayora      EC  -0.74  -90.35     86.00        48           0
# 3        Avarua      CK -21.21 -159.78     80.60        83          22
# 4     Bathsheba      BB  13.22  -59.52     78.80        83          75
# 5           Vao      NC -22.67  167.48     77.90        83         100
# 6   Port Alfred      ZA -33.59   26.89     68.00        87           0
# 7       Inyonga      TZ  -6.72   32.07     68.13        81         100
# 8         Alofi      NU -19.06 -169.92     75.20       100          83
# 9        Xinzhi      CN  36.50  111.70     14.56        58           0
#
#    Wind Speed Current Description
# 0        4.12     overcast clouds
# 1       14.12           clear sky
# 2       18.34           clear sky
# 3        8.05          light rain
# 4       11.41       broken clouds
# 5       25.66          light rain
# 6        6.29           clear sky
# 7        1.77     overcast clouds
# 8        1.12          light rain
# 9        3.06           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
